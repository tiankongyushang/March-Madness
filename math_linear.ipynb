# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.externals import joblib
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (auc, classification_report, roc_auc_score, accuracy_score,
                             f1_score, log_loss, roc_curve, confusion_matrix, precision_score, recall_score)
from sklearn.preprocessing import StandardScaler
from math import sin, cos, sqrt, atan2, radians
import random
import statsmodels.api as sm

# %%
mm_data = pd.read_csv('MM_DATA1.csv')

# %%
def distance(lat1, lon1, lat2, lon2):

    # approximate radius of earth in km
    R = 6373.0

    lat1 = radians(lat1)
    lon1 = radians(lon1)
    lat2 = radians(lat2)
    lon2 = radians(lon2)

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    distance = R * c
    
    return distance

# %%
mm_data['dist1'] = mm_data.apply(lambda row: distance(row['host_lat'], row['host_long'], row['team1_lat'], row['team1_long']), axis=1)
mm_data['dist2'] = mm_data.apply(lambda row: distance(row['host_lat'], row['host_long'], row['team2_lat'], row['team2_long']), axis=1)

# %%
mm_data['diff_dist'] = mm_data['dist1'] - mm_data['dist2']

# %%
mm_data['exp_win1'] = (mm_data['team1_adjoe']**11.5)/ ((mm_data['team1_adjde']**11.5)+(mm_data['team1_adjoe']**11.5))
mm_data['exp_win2'] = (mm_data['team2_adjoe']**11.5)/ ((mm_data['team2_adjde']**11.5)+(mm_data['team2_adjoe']**11.5))

# %%
mm_data['team1_log5'] = (mm_data['exp_win1'] - (mm_data['exp_win1']*mm_data['exp_win2']))/ (mm_data['exp_win1']+mm_data['exp_win2']-(2*mm_data['exp_win1']*mm_data['exp_win2']))

# %%
mm_data[['team1_adjoe','team1_id','season','team2_id','team1_adjde','exp_win1','exp_win2','team1_log5']].head()
# Out:
#    team1_adjoe  team1_id  season  team2_id  team1_adjde  exp_win1  exp_win2  \
# 0     111.4954      1104    2002      1194      93.8770  0.878465  0.411542
# 1     117.3877      1112    2002      1364      96.9262  0.900485  0.707177
# 2     118.5999      1181    2002      1457      87.7504  0.969660  0.367453
# 3     109.6136      1231    2002      1428      89.9224  0.906968  0.812015
# 4     115.0406      1242    2002      1221      90.5399  0.940149  0.501475
#
#    team1_log5
# 0    0.911780
# 1    0.789333
# 2    0.982148
# 3    0.692962
# 4    0.939816

# %%
mm_data['seed_diff'] = mm_data['team1_seed'] - mm_data['team2_seed']

# %%
mm_data[['game_id','exp_win1','exp_win2','team2_score','team1_score','diff_dist','team1_log5','team1_id','team2_id']].head()
# Out:
#           game_id  exp_win1  exp_win2  team2_score  team1_score    diff_dist  \
# 0  2002-1104-1194  0.878465  0.411542           78           86   -88.820532
# 1  2002-1112-1364  0.900485  0.707177           81           86  -697.542289
# 2  2002-1181-1457  0.969660  0.367453           37           84  -191.666514
# 3  2002-1231-1428  0.906968  0.812015           56           75  2148.977013
# 4  2002-1242-1221  0.940149  0.501475           59           70   -39.535171
#
#    team1_log5  team1_id  team2_id
# 0    0.911780      1104      1194
# 1    0.789333      1112      1364
# 2    0.982148      1181      1457
# 3    0.692962      1231      1428
# 4    0.939816      1242      1221

# %%
mm_data.dropna(subset=['team1_log5'], inplace=True)

# %%
mm_data.head()
# Out:
#    team1_id  team1_score  team2_id  team2_score  team1_seed  team2_seed  \
# 0      1104           86      1194           78           2          15
# 1      1112           86      1364           81           3          14
# 2      1181           84      1457           37           1          16
# 3      1231           75      1428           56           5          12
# 4      1242           70      1221           59           1          16
#
#    season  host_lat  host_long  team1_lat    ...      team2_adjde  \
# 0    2002   35.6017   -77.3725  33.214400    ...          99.9263
# 1    2002   35.1107  -106.6100  32.232071    ...          97.6704
# 2    2002   35.6017   -77.3725  36.001590    ...          99.9754
# 3    2002   38.5556  -121.4689  39.166383    ...          95.6459
# 4    2002   38.6272   -90.1978  38.957351    ...          96.6499
#
#           game_id  result        dist1        dist2    diff_dist  exp_win1  \
# 0  2002-1104-1194       1   970.079692  1058.900224   -88.820532  0.878465
# 1  2002-1112-1364       1   513.690472  1211.232761  -697.542289  0.900485
# 2  2002-1181-1457       1   148.431171   340.097686  -191.666514  0.969660
# 3  2002-1231-1428       1  3008.248664   859.271651  2148.977013  0.906968
# 4  2002-1242-1221       1   439.123404   478.658575   -39.535171  0.940149
#
#    exp_win2  team1_log5  seed_diff
# 0  0.411542    0.911780        -13
# 1  0.707177    0.789333        -11
# 2  0.367453    0.982148        -15
# 3  0.812015    0.692962         -7
# 4  0.501475    0.939816        -15
#
# [5 rows x 90 columns]

# %%
result0 = mm_data.sample(n=488, frac=None, replace=False,  weights=None, random_state=1, axis=None)

# %%
result1 = mm_data.drop(labels=result0.axes[0])

# %%
result0['result']=0

# %%
result0.head()
# Out:
#      team1_id  team1_score  team2_id  team2_score  team1_seed  team2_seed  \
# 932      1268           79      1355           74           5          12
# 724      1332           68      1329           55          12           5
# 525      1437           73      1352           70           2          15
# 6        1246           83      1434           68           4          13
# 248      1228           90      1112           89           1           3
#
#      season  host_lat  host_long  team1_lat    ...      team2_adjde  \
# 932    2016   47.6589  -117.4250  38.988607    ...         100.3090
# 724    2013   42.6875   -83.2342  44.044515    ...          90.3122
# 525    2010   43.0500   -87.9500  40.039388    ...         100.2647
# 6      2002   38.6272   -90.1978  38.028081    ...          96.7884
# 248    2005   30.2500   -97.7500  39.730827    ...          95.3458
#
#             game_id  result        dist1        dist2    diff_dist  exp_win1  \
# 932  2016-1268-1355       0  3372.406850  1632.597996  1739.808854  0.906823
# 724  2013-1332-1329       0  3193.515857  1392.697047  1800.818810  0.818842
# 525  2010-1437-1352       0  1100.175416   700.367644   399.807772  0.903115
# 6    2002-1246-1434       0   500.611426   414.108067    86.503358  0.895478
# 248  2005-1228-1112       0  1255.694798  1273.745860   -18.051062  0.971417
#
#      exp_win2  team1_log5  seed_diff
# 932  0.741060    0.772759         -7
# 724  0.882985    0.374610          7
# 525  0.474357    0.911734        -13
# 6    0.801440    0.679753         -9
# 248  0.886596    0.812983         -2
#
# [5 rows x 90 columns]

# %%
result0['diff_dist']=result0['diff_dist']*-1

# %%
result0['team1_log5']=1-result0['team1_log5']

# %%
result0['seed_diff']=result0['seed_diff']*(-1)

# %%
result0['team2_adjde']=result0['team2_adjde']*-1

# %%
result0.head()
# Out:
#      team1_id  team1_score  team2_id  team2_score  team1_seed  team2_seed  \
# 932      1268           79      1355           74           5          12
# 724      1332           68      1329           55          12           5
# 525      1437           73      1352           70           2          15
# 6        1246           83      1434           68           4          13
# 248      1228           90      1112           89           1           3
#
#      season  host_lat  host_long  team1_lat    ...      team2_adjde  \
# 932    2016   47.6589  -117.4250  38.988607    ...        -100.3090
# 724    2013   42.6875   -83.2342  44.044515    ...         -90.3122
# 525    2010   43.0500   -87.9500  40.039388    ...        -100.2647
# 6      2002   38.6272   -90.1978  38.028081    ...         -96.7884
# 248    2005   30.2500   -97.7500  39.730827    ...         -95.3458
#
#             game_id  result        dist1        dist2    diff_dist  exp_win1  \
# 932  2016-1268-1355       0  3372.406850  1632.597996 -1739.808854  0.906823
# 724  2013-1332-1329       0  3193.515857  1392.697047 -1800.818810  0.818842
# 525  2010-1437-1352       0  1100.175416   700.367644  -399.807772  0.903115
# 6    2002-1246-1434       0   500.611426   414.108067   -86.503358  0.895478
# 248  2005-1228-1112       0  1255.694798  1273.745860    18.051062  0.971417
#
#      exp_win2  team1_log5  seed_diff
# 932  0.741060    0.227241          7
# 724  0.882985    0.625390         -7
# 525  0.474357    0.088266         13
# 6    0.801440    0.320247          9
# 248  0.886596    0.187017          2
#
# [5 rows x 90 columns]

# %%
mm_train = pd.concat([result0, result1])

# %%
mm_train.set_index('game_id',inplace =True)

# %%
mm_train.head()
# Out:
#                 team1_id  team1_score  team2_id  team2_score  team1_seed  \
# game_id
# 2016-1268-1355      1268           79      1355           74           5
# 2013-1332-1329      1332           68      1329           55          12
# 2010-1437-1352      1437           73      1352           70           2
# 2002-1246-1434      1246           83      1434           68           4
# 2005-1228-1112      1228           90      1112           89           1
#
#                 team2_seed  season  host_lat  host_long  team1_lat    ...      \
# game_id                                                               ...
# 2016-1268-1355          12    2016   47.6589  -117.4250  38.988607    ...
# 2013-1332-1329           5    2013   42.6875   -83.2342  44.044515    ...
# 2010-1437-1352          15    2010   43.0500   -87.9500  40.039388    ...
# 2002-1246-1434          13    2002   38.6272   -90.1978  38.028081    ...
# 2005-1228-1112           3    2005   30.2500   -97.7500  39.730827    ...
#
#                 team2_de  team2_adjde  result        dist1        dist2  \
# game_id
# 2016-1268-1355  100.0370    -100.3090       0  3372.406850  1632.597996
# 2013-1332-1329   91.5887     -90.3122       0  3193.515857  1392.697047
# 2010-1437-1352   96.8173    -100.2647       0  1100.175416   700.367644
# 2002-1246-1434   94.0668     -96.7884       0   500.611426   414.108067
# 2005-1228-1112   97.7107     -95.3458       0  1255.694798  1273.745860
#
#                   diff_dist  exp_win1  exp_win2  team1_log5  seed_diff
# game_id
# 2016-1268-1355 -1739.808854  0.906823  0.741060    0.227241          7
# 2013-1332-1329 -1800.818810  0.818842  0.882985    0.625390         -7
# 2010-1437-1352  -399.807772  0.903115  0.474357    0.088266         13
# 2002-1246-1434   -86.503358  0.895478  0.801440    0.320247          9
# 2005-1228-1112    18.051062  0.971417  0.886596    0.187017          2
#
# [5 rows x 89 columns]

# %%
##test data

# %%
mm_1718 = pd.read_csv('MM_DATA1_1718.csv')

# %%
mm_1718['dist1'] = mm_data.apply(lambda row: distance(row['host_lat'], row['host_long'], row['team1_lat'], row['team1_long']), axis=1)
mm_1718['dist2'] = mm_data.apply(lambda row: distance(row['host_lat'], row['host_long'], row['team2_lat'], row['team2_long']), axis=1)

# %%
mm_1718['diff_dist'] = mm_1718['dist1'] - mm_1718['dist2']

# %%
mm_1718['exp_win1'] = (mm_1718['team1_adjoe']**11.5)/ ((mm_1718['team1_adjde']**11.5)+(mm_1718['team1_adjoe']**11.5))
mm_1718['exp_win2'] = (mm_1718['team2_adjoe']**11.5)/ ((mm_1718['team2_adjde']**11.5)+(mm_1718['team2_adjoe']**11.5))

# %%
mm_1718['team1_log5'] = (mm_1718['exp_win1'] - (mm_1718['exp_win1']*mm_1718['exp_win2']))/ (mm_1718['exp_win1']+mm_1718['exp_win2']-(2*mm_1718['exp_win1']*mm_1718['exp_win2']))

# %%
mm_1718['seed_diff'] = mm_1718['team1_seed'] - mm_1718['team2_seed']

# %%
mm_1718.dropna(subset=['team1_log5'], inplace=True)

# %%
test_result0 = mm_1718.sample(n=67, frac=None, replace=False,  weights=None, random_state=1, axis=None)

# %%
test_result0['diff_dist']=test_result0['diff_dist']*-1
test_result0['team1_log5']=1-test_result0['team1_log5']
test_result0['seed_diff']=test_result0['seed_diff']*(-1)

# %%
test_result1 = mm_1718.drop(labels=test_result0.axes[0])

# %%
test_result0['result']=0

# %%
mm_test = pd.concat([test_result0, test_result1])

# %%
scaler = StandardScaler()
mm_train_scaled = scaler.fit_transform(mm_train[['team1_log5','diff_dist','seed_diff']])
logit = LogisticRegression()
logit.fit(mm_train_scaled, mm_train['result'])
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
#mm_test = mm_1718

# %%
mm_test['preds'] = logit.predict_proba(scaler.fit_transform(mm_test[['team1_log5','diff_dist','seed_diff']]))[:,1]
mm_test['prediction'] = logit.predict(scaler.fit_transform(mm_test[['team1_log5','diff_dist','seed_diff']]))

# %%
#mm_test.set_index('game_id',inplace = True)

# %%
mm_test[['preds','prediction']]
# Out:
#                    preds  prediction
# game_id
# 2017-1458-1437  0.704610           1
# 2017-1112-1388  0.480877           0
# 2018-1305-1400  0.212954           0
# 2017-1139-1457  0.108457           0
# 2017-1314-1332  0.377826           0
# 2018-1276-1222  0.537011           1
# 2017-1196-1458  0.346491           0
# 2017-1452-1137  0.101311           0
# 2017-1242-1345  0.432047           0
# 2018-1243-1246  0.596590           1
# 2018-1393-1113  0.703859           1
# 2018-1401-1314  0.632611           1
# 2017-1124-1425  0.103260           0
# 2017-1376-1124  0.713886           1
# 2018-1199-1281  0.433714           0
# 2018-1155-1120  0.565131           1
# 2017-1417-1245  0.084539           0
# 2018-1138-1112  0.643640           1
# 2018-1403-1345  0.653340           1
# 2017-1438-1423  0.173088           0
# 2017-1314-1116  0.160132           0
# 2018-1243-1166  0.659505           1
# 2017-1242-1277  0.173093           0
# 2017-1348-1166  0.519485           1
# 2017-1112-1315  0.076764           0
# 2018-1181-1393  0.130241           0
# 2018-1199-1462  0.699112           1
# 2017-1455-1173  0.209286           0
# 2017-1462-1112  0.788601           1
# 2018-1242-1371  0.246738           0
# ...                  ...         ...
# 2018-1242-1335  0.788589           1
# 2018-1181-1233  0.883546           1
# 2018-1326-1355  0.689468           1
# 2018-1276-1285  0.607970           1
# 2018-1246-1172  0.455467           0
# 2018-1222-1361  0.687378           1
# 2018-1196-1382  0.520941           1
# 2018-1420-1438  0.073411           0
# 2018-1403-1372  0.696307           1
# 2018-1401-1344  0.625465           1
# 2018-1314-1252  0.810814           1
# 2018-1260-1274  0.618287           1
# 2018-1393-1395  0.317009           0
# 2018-1452-1293  0.487423           0
# 2018-1267-1455  0.229388           0
# 2018-1437-1104  0.878480           1
# 2018-1181-1348  0.757123           1
# 2018-1211-1326  0.799760           1
# 2018-1260-1397  0.485640           0
# 2018-1403-1196  0.692625           1
# 2018-1393-1277  0.130535           0
# 2018-1243-1420  0.698064           1
# 2018-1305-1153  0.176211           0
# 2018-1199-1211  0.143703           0
# 2018-1437-1452  0.700186           1
# 2018-1437-1403  0.672728           1
# 2018-1242-1181  0.305950           0
# 2018-1260-1243  0.697304           1
# 2018-1276-1199  0.708483           1
# 2018-1276-1260  0.626833           1
#
# [134 rows x 2 columns]

# %%
#mm_test['re']=1

# %%
log_loss(mm_test['result'].values, mm_test['preds'].values)
# Out:
# 0.5717815106560902
